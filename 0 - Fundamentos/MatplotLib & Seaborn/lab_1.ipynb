# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.drop("Cabin", axis=1, inplace=True)

sobrevivencia_sexo = df.groupby('Sex')['Survived'].mean() * 100


plt.figure(figsize=(8, 5))
#plt.bar(sobrevivencia_sexo.index, sobrevivencia_sexo.values)
#plt.scatter(sobrevivencia_sexo.index, sobrevivencia_sexo.values)
#plt.hist(sobrevivencia_sexo.values)
#sns.barplot(x=sobrevivencia_sexo.index, y=sobrevivencia_sexo.values, hue = sobrevivencia_sexo.index, palette='viridis')
#sns.histplot(sobrevivencia_sexo.values)
#sns.boxplot(x=sobrevivencia_sexo.index, y=sobrevivencia_sexo.values)
#sns.heatmap(df.corr(numeric_only=True), annot=True)
#sns.scatterplot(x='Age', y='Fare', data=df)	
#sns.countplot(x='Sex', data=df)
sns.pairplot(df)
plt.title("TESTE FEATURES MATPLOT E SEABORN")
plt.ylabel("TESTE FEATURES MATPLOT E SEABORN")
plt.show()
